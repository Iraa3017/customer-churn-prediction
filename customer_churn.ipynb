# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df_churn = pd.read_csv('customer_churn.csv')

# %%
df_churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df_churn.shape
# Out:
# (7043, 21)

# %%
df_churn
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df_churn.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df_churn.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Select only numeric columns
numeric_df = df_churn.select_dtypes(include=[np.number])

# Calculate the correlation matrix
churn_corr = numeric_df.corr()

# %%
import seaborn as sns

# Create a heatmap

plt.figure(figsize=(8, 6))

sns.heatmap(churn_corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)

plt.title('Correlation Heatmap')

plt.show()

# %%
#plot chruners and non chruners

df_churn['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# '''highly imbalanced dataset'''

# %%
df_churn['Churn'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Churn'>

# %% [markdown]
# '''earlier total charges was showing no null values because it was object dtype, after converting to float, it shows 11 null values'''

# %%
#convert total charges to numeric

df_churn['TotalCharges'] = pd.to_numeric(df_churn['TotalCharges'], errors='coerce')

df_churn['TotalCharges'].isnull().sum()

df_churn['TotalCharges'].fillna(df_churn['TotalCharges'].mean(), inplace=True)

df_churn['TotalCharges'].isnull().sum()
# Out:
# /var/folders/x5/hcnq9sqs1_l___s5zs9pxn9h0000gn/T/ipykernel_61352/3888455921.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_churn['TotalCharges'].fillna(df_churn['TotalCharges'].mean(), inplace=True)
# 0

# %%
df_churn.drop('customerID', axis=1, inplace=True)

# %%
df_churn.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# ###univariate analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame, and 'Churn' is the column indicating churn status
# List of categorical features you want to plot
categorical_features = [
    'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 
    'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 
    'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 
    'Contract', 'PaperlessBilling', 'PaymentMethod'
]


fig, axes = plt.subplots(4, 4, figsize=(16, 12))

axes = axes.flatten()

# Loop through each feature and plot it
for i, feature in enumerate(categorical_features):
    # Plot the countplot for churners (Churn = 'Yes') vs non-churners (Churn = 'No')
    sns.countplot(x=feature, hue='Churn', data=df_churn, ax=axes[i], palette='Set2')
    
    # Set the title for each subplot
    axes[i].set_title(f'Churn vs {feature}')
    
    # Rotate x-axis labels if needed
    for label in axes[i].get_xticklabels():
        label.set_rotation(45)
    
# Adjust layout to avoid overlapping subplots
plt.tight_layout()
plt.show()

# %%
df_churn['Churn'] = df_churn['Churn'].map({'Yes': 1, 'No': 0})

# %%
df_churn.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df_churn
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
# Convert boolean columns to 1 and 0
df_churn[df_churn.select_dtypes(include=['bool']).columns] = df_churn.select_dtypes(include=['bool']).astype(int)

# Now apply pd.get_dummies if needed
df_churn = pd.get_dummies(df_churn)
df_churn.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0       1           29.85         29.85      0           True
# 1              0      34           56.95       1889.50      0          False
# 2              0       2           53.85        108.15      1          False
# 3              0      45           42.30       1840.75      0          False
# 4              0       2           70.70        151.65      1           True
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0        False       False         True           True  ...
# 1         True        True        False           True  ...
# 2         True        True        False           True  ...
# 3         True        True        False           True  ...
# 4        False        True        False           True  ...
#
#    StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                False                     True              False
# ...

# %%
#relationship between total charges and monthly charges

plt.figure(figsize=(8, 6))

plt.bar(df_churn['MonthlyCharges'], df_churn['TotalCharges'])

plt.xlabel('Monthly Charges')

plt.ylabel('Total Charges')

plt.title('Monthly Charges vs. Total Charges')
# Out:
# Text(0.5, 1.0, 'Monthly Charges vs. Total Charges')

# %%
#churn for monthly charges

plt.figure(figsize=(8, 6))

sns.kdeplot(df_churn.loc[df_churn['Churn'] == 0, 'MonthlyCharges'], label='Churn: No', shade=True)

sns.kdeplot(df_churn.loc[df_churn['Churn'] == 1, 'MonthlyCharges'], label='Churn: Yes', shade=True)

plt.xlabel('Monthly Charges')

plt.legend()

plt.ylabel('Density')

plt.title('Monthly Charges Distribution - Churn vs. No Churn')

plt.show()
# Out:
# /var/folders/x5/hcnq9sqs1_l___s5zs9pxn9h0000gn/T/ipykernel_61352/3247154916.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_churn.loc[df_churn['Churn'] == 0, 'MonthlyCharges'], label='Churn: No', shade=True)
# /var/folders/x5/hcnq9sqs1_l___s5zs9pxn9h0000gn/T/ipykernel_61352/3247154916.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_churn.loc[df_churn['Churn'] == 1, 'MonthlyCharges'], label='Churn: Yes', shade=True)

# %%
#churn for monthly charges

plt.figure(figsize=(8, 6))

sns.kdeplot(df_churn.loc[df_churn['Churn'] == 0, 'TotalCharges'], label='Churn: No', shade=True)

sns.kdeplot(df_churn.loc[df_churn['Churn'] == 1, 'TotalCharges'], label='Churn: Yes', shade=True)

plt.xlabel('Total Charges')

plt.legend()

plt.ylabel('Density')

plt.title('Monthly Charges Distribution - Churn vs. No Churn')

plt.show()
# Out:
# /var/folders/x5/hcnq9sqs1_l___s5zs9pxn9h0000gn/T/ipykernel_61352/1260645855.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_churn.loc[df_churn['Churn'] == 0, 'TotalCharges'], label='Churn: No', shade=True)
# /var/folders/x5/hcnq9sqs1_l___s5zs9pxn9h0000gn/T/ipykernel_61352/1260645855.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_churn.loc[df_churn['Churn'] == 1, 'TotalCharges'], label='Churn: Yes', shade=True)

# %%
df_churn
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  \
# 0                 0       1           29.85         29.85      0
# 1                 0      34           56.95       1889.50      0
# 2                 0       2           53.85        108.15      1
# 3                 0      45           42.30       1840.75      0
# 4                 0       2           70.70        151.65      1
# ...             ...     ...             ...           ...    ...
# 7038              0      24           84.80       1990.50      0
# 7039              0      72          103.20       7362.90      0
# 7040              0      11           29.60        346.45      0
# 7041              1       4           74.40        306.60      1
# 7042              0      66          105.65       6844.50      0
#
#       gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0              True        False       False         True           True  ...
# ...

# %%
plt.figure(figsize=(8, 6))

sns.kdeplot(df_churn.loc[df_churn['Churn'] == 0, 'tenure'], label='Churn: No', shade=True)

sns.kdeplot(df_churn.loc[df_churn['Churn'] == 1, 'tenure'], label='Churn: Yes', shade=True)

plt.xlabel('Tenure')

plt.legend()
# Out:
# /var/folders/x5/hcnq9sqs1_l___s5zs9pxn9h0000gn/T/ipykernel_61352/8627253.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_churn.loc[df_churn['Churn'] == 0, 'tenure'], label='Churn: No', shade=True)
# /var/folders/x5/hcnq9sqs1_l___s5zs9pxn9h0000gn/T/ipykernel_61352/8627253.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_churn.loc[df_churn['Churn'] == 1, 'tenure'], label='Churn: Yes', shade=True)

# %%
import matplotlib.pyplot as plt

# Filter data for customers who have churned (Churn == 1) and not churned (Churn == 0)
churned = df_churn[df_churn['Churn'] == 1]
not_churned = df_churn[df_churn['Churn'] == 0]

# Create a new figure for the plot
plt.figure(figsize=(10, 6))

# Plotting lines for each variable, separated by churn status

# Tenure
plt.plot(churned['tenure'], label='Tenure (Churned)', color='red', alpha=0.7)
plt.plot(not_churned['tenure'], label='Tenure (Not Churned)', color='blue', alpha=0.7)

# Monthly Charges
plt.plot(churned['MonthlyCharges'], label='Monthly Charges (Churned)', color='orange', alpha=0.7)
plt.plot(not_churned['MonthlyCharges'], label='Monthly Charges (Not Churned)', color='green', alpha=0.7)

# Total Charges
plt.plot(churned['TotalCharges'], label='Total Charges (Churned)', color='purple', alpha=0.7)
plt.plot(not_churned['TotalCharges'], label='Total Charges (Not Churned)', color='cyan', alpha=0.7)

# Add labels and title
plt.xlabel('Index (Customer ID or Record)')
plt.ylabel('Value')
plt.title('Line Plots of Tenure, Monthly Charges, and Total Charges by Churn Status')

# Show legend
plt.legend()

# Display the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))
df_churn.correlation = df_churn.corr().sort_values(by='Churn', ascending=False)['Churn']

df_churn.correlation.plot(kind='bar')
# Out:
# /var/folders/x5/hcnq9sqs1_l___s5zs9pxn9h0000gn/T/ipykernel_61352/2703453606.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_churn.correlation = df_churn.corr().sort_values(by='Churn', ascending=False)['Churn']
# <Axes: >

# %%
'''factors like tenure, monthly charges, total charges, and contract type have a significant impact on churn.

Customers with shorter tenure, higher monthly charges, and higher total charges are more likely to churn.

Customers with a month-to-month contract are more likely to churn compared to customers with one or two-year contracts.

Customers with fiber optic internet service are more likely to churn compared to customers with DSL internet service.

Customers without tech support are more likely to churn compared to customers with tech support.

Customers without online security are more likely to churn compared to customers with online security.

gender, senior citizen, partner, dependents, phone service, multiple lines, online backup, device protection, streaming TV, streaming movies, and paperless billing do not have a significant impact on churn.'''
# Out:
# 'factors like tenure, monthly charges, total charges, and contract type have a significant impact on churn.\n\nCustomers with shorter tenure, higher monthly charges, and higher total charges are more likely to churn.\n\nCustomers with a month-to-month contract are more likely to churn compared to customers with one or two-year contracts.\n\nCustomers with fiber optic internet service are more likely to churn compared to customers with DSL internet service.\n\nCustomers without tech support are more likely to churn compared to customers with tech support.\n\nCustomers without online security are more likely to churn compared to customers with online security.\n\ngender, senior citizen, partner, dependents, phone service, multiple lines, online backup, device protection, streaming TV, streaming movies, and paperless billing do not have a significant impact on churn.'

# %% [markdown]
# ###bivariate analysis

# %%
df_churn1=pd.read_csv('customer_churn.csv')
#create a new df with only the churners

df_churn1 = df_churn1[df_churn1['Churn'] == 'Yes']

df_churn1.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 2             No             DSL            Yes  ...               No
# 4             No     Fiber optic             No  ...               No
# 5            Yes     Fiber optic             No  ...              Yes
# 8            Yes     Fiber optic             No  ...              Yes
# 13           Yes     Fiber optic             No  ...              Yes
#
# ...

# %%
sns.set(style="whitegrid")
# Verify the column names in df_churn
print(df_churn1.columns)
plt.figure(figsize=(10, 6))
# Using countplot with both Partner and Gender on the x-axis and Churn as hue
sns.countplot(data=df_churn1, x='Partner', hue='gender', palette='Set2', 
              hue_order=['Male', 'Female'], dodge=True)

# Add title and labels
plt.title('Churn by Partner and Gender')
plt.xlabel('Partner (Yes/No)')
plt.ylabel('Count')
plt.legend(title='Gender', loc='upper right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure 'MonthlyCharges' and 'TotalCharges' are numeric
df_churn1['MonthlyCharges'] = pd.to_numeric(df_churn1['MonthlyCharges'], errors='coerce')
df_churn1['TotalCharges'] = pd.to_numeric(df_churn1['TotalCharges'], errors='coerce')

# Drop rows with NaN values in 'MonthlyCharges' or 'TotalCharges'
df_churn1.dropna(subset=['MonthlyCharges', 'TotalCharges'], inplace=True)

# Create bins for MonthlyCharges and TotalCharges
df_churn1['MonthlyCharges_binned'] = pd.cut(df_churn1['MonthlyCharges'], bins=5)
df_churn1['TotalCharges_binned'] = pd.cut(df_churn1['TotalCharges'], bins=5)

# Set the style for better visuals
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))

# Using countplot with binned MonthlyCharges and TotalCharges on the x-axis and Churn as hue
sns.countplot(data=df_churn1, x='MonthlyCharges_binned', hue='TotalCharges_binned', palette='Set2', dodge=True)

# Add title and labels
plt.title('Churn by Binned MonthlyCharges and TotalCharges')
plt.xlabel('MonthlyCharges (Binned)')
plt.ylabel('Count')
plt.legend(title='TotalCharges (Binned)', loc='upper right')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ###model building part

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier

# %%
df_churn.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0       1           29.85         29.85      0           True
# 1              0      34           56.95       1889.50      0          False
# 2              0       2           53.85        108.15      1          False
# 3              0      45           42.30       1840.75      0          False
# 4              0       2           70.70        151.65      1           True
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0        False       False         True           True  ...
# 1         True        True        False           True  ...
# 2         True        True        False           True  ...
# 3         True        True        False           True  ...
# 4        False        True        False           True  ...
#
#    StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                False                     True              False
# ...

# %%
y=df_churn['Churn']
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7043, dtype: int64

# %%
x=df_churn.drop('Churn', axis=1)
x
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Female  \
# 0                 0       1           29.85         29.85           True
# 1                 0      34           56.95       1889.50          False
# 2                 0       2           53.85        108.15          False
# 3                 0      45           42.30       1840.75          False
# 4                 0       2           70.70        151.65           True
# ...             ...     ...             ...           ...            ...
# 7038              0      24           84.80       1990.50          False
# 7039              0      72          103.20       7362.90           True
# 7040              0      11           29.60        346.45           True
# 7041              1       4           74.40        306.60          False
# 7042              0      66          105.65       6844.50          False
#
#       gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# ...

# %%
len(x.columns)
# Out:
# 45

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model=LogisticRegression()

model.fit(x_train, y_train)

y_pred=model.predict(x_test)

accuracy_score(y_test, y_pred)

print(classification_report(y_test, y_pred))

scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)

x_test_scaled = scaler.transform(x_test)

model=LogisticRegression()

model.fit(x_train_scaled, y_train)

y_pred=model.predict(x_test_scaled)

accuracy_score(y_test, y_pred)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88      1036
#            1       0.69      0.58      0.63       373
#
#     accuracy                           0.82      1409
#    macro avg       0.78      0.74      0.76      1409
# weighted avg       0.81      0.82      0.82      1409
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88      1036
#            1       0.69      0.60      0.64       373
#
#     accuracy                           0.82      1409
#    macro avg       0.77      0.75      0.76      1409
# weighted avg       0.81      0.82      0.82      1409
# /Users/irasinghal/anaconda3/envs/myenv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %%
model=DecisionTreeClassifier(criterion='gini',max_depth=5)
model.fit(x_train, y_train)
y_pred=model.predict(x_test)
accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      1036
#            1       0.62      0.64      0.63       373
#
#     accuracy                           0.80      1409
#    macro avg       0.74      0.75      0.75      1409
# weighted avg       0.80      0.80      0.80      1409

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=200, random_state=42)
model.fit(x_train, y_train)
y_pred=model.predict(x_test)
accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87      1036
#            1       0.66      0.48      0.56       373
#
#     accuracy                           0.80      1409
#    macro avg       0.75      0.70      0.71      1409
# weighted avg       0.78      0.80      0.79      1409

# %%
#build a simple neural network uisng keras and tensorflow

import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(20, input_shape=(45,), activation='relu'),
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(x_train, y_train, epochs=50)

model.evaluate(x_test, y_test)

y_pred = model.predict(x_test)

y_pred[:5]

y_pred = np.round(y_pred).flatten()

y_pred[:5]

accuracy_score(y_test, y_pred)

print(classification_report(y_test, y_pred))
# Out:
# Epoch 1/50
# /Users/irasinghal/anaconda3/envs/myenv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - accuracy: 0.6663 - loss: 10.7834
# Epoch 2/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - accuracy: 0.6889 - loss: 1.8277
# Epoch 3/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - accuracy: 0.7483 - loss: 1.1995
# Epoch 4/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - accuracy: 0.7426 - loss: 1.1065
# Epoch 5/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step - accuracy: 0.7540 - loss: 1.0183
# Epoch 6/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - accuracy: 0.7617 - loss: 1.1237
# Epoch 7/50
# ...

# %%
#upsample the minority class to balance the dataset

from sklearn.utils import resample

# Separate majority and minority classes

df_majority = df_churn[df_churn['Churn'] == 0]

df_minority = df_churn[df_churn['Churn'] == 1]

# Upsample minority class

df_minority_upsampled = resample(df_minority, replace=True, n_samples=5163, random_state=42)

# Combine majority class with upsampled minority class

df_upsampled = pd.concat([df_majority, df_minority_upsampled])

# Display new class counts

df_upsampled['Churn'].value_counts()

y = df_upsampled['Churn']

x = df_upsampled.drop('Churn', axis=1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model = keras.Sequential([

    keras.layers.Dense(45, input_shape=(45,), activation='relu'),

    keras.layers.Dense(20, activation='relu'),

    keras.layers.Dense(1, activation='sigmoid')

])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(x_train, y_train, epochs=50)

model.evaluate(x_test, y_test)

y_pred = model.predict(x_test)

y_pred = np.round(y_pred).flatten()

accuracy_score(y_test, y_pred)

print(classification_report(y_test, y_pred))
# Out:
# Epoch 1/50
# /Users/irasinghal/anaconda3/envs/myenv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - accuracy: 0.5519 - loss: 13.3812
# Epoch 2/50
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step - accuracy: 0.7200 - loss: 0.6522
# Epoch 3/50
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - accuracy: 0.7252 - loss: 0.6271
# Epoch 4/50
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 354us/step - accuracy: 0.6987 - loss: 0.9066
# Epoch 5/50
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step - accuracy: 0.7162 - loss: 0.8330
# Epoch 6/50
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - accuracy: 0.7390 - loss: 0.6706
# Epoch 7/50
# ...

# %%
#use smote to balance the dataset

from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='minority')

x_smote, y_smote = smote.fit_resample(x, y)

y_smote.value_counts()

x_train, x_test, y_train, y_test = train_test_split(x_smote, y_smote, test_size=0.2, random_state=42)

model = keras.Sequential([

    keras.layers.Dense(20, input_shape=(45,), activation='relu'),

    keras.layers.Dense(10, activation='relu'),

    keras.layers.Dense(1, activation='sigmoid')

])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(x_train, y_train, epochs=50)

model.evaluate(x_test, y_test)

y_pred = model.predict(x_test)

y_pred = np.round(y_pred).flatten()

accuracy_score(y_test, y_pred)

print(classification_report(y_test, y_pred))
# Out:
# Epoch 1/50
# /Users/irasinghal/anaconda3/envs/myenv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step - accuracy: 0.6267 - loss: 11.1550
# Epoch 2/50
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - accuracy: 0.7035 - loss: 0.8313
# Epoch 3/50
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 342us/step - accuracy: 0.7250 - loss: 0.7963
# Epoch 4/50
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - accuracy: 0.7229 - loss: 0.7922
# Epoch 5/50
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - accuracy: 0.7029 - loss: 1.0112
# Epoch 6/50
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - accuracy: 0.7233 - loss: 0.7191
# Epoch 7/50
# ...

# %%
#use smoteen

from imblearn.combine import SMOTEENN

smote_enn = SMOTEENN(sampling_strategy='minority')

x_smoteenn, y_smoteenn = smote_enn.fit_resample(x, y)

y_smoteenn.value_counts()

x_train, x_test, y_train, y_test = train_test_split(x_smoteenn, y_smoteenn, test_size=0.2, random_state=42)

model=RandomForestClassifier(n_estimators=200, random_state=42, max_depth=5, criterion='gini',min_samples_leaf=6)

model.fit(x_train, y_train)

y_pred=model.predict(x_test)

accuracy_score(y_test, y_pred)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86       645
#            1       0.87      0.88      0.88       744
#
#     accuracy                           0.87      1389
#    macro avg       0.87      0.87      0.87      1389
# weighted avg       0.87      0.87      0.87      1389

# %%
#difference between smote, smoteen 
#SMOTE (Synthetic Minority Over Sampling Technique) is an over-sampling technique that generates synthetic samples from the minority class. It is used to balance the class distribution. SMOTE works by selecting examples that are close in the feature space, drawing a line between the examples in the feature space and drawing a new sample at a point along that line.

#SMOTEENN combines the SMOTE and Edited Nearest Neighbors (ENN) algorithms. SMOTEENN first oversamples the minority class using SMOTE and then cleans the resulting data using ENN. ENN removes examples whose class label differs from the class of at least half of its k nearest neighbors. SMOTEENN is useful when the dataset has a large number of noisy examples.

# %%
import pickle

# Save the model to disk

filename = 'customer_churn.pkl'

pickle.dump(model, open(filename, 'wb'))

# Load the model from disk

loaded_model = pickle.load(open(filename
                                
                                , 'rb'))

# Test the loaded model on the test data

result = loaded_model.score(x_test, y_test)

print(f'Test accuracy: {result}')
# Out:
# Test accuracy: 0.8668106551475881
